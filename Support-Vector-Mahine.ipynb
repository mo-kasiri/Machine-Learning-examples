# %%
import numpy as np
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
plt.plot(X[:, 0][iris["target"]==0], X[:, 1][iris["target"]==0], "b.", label="Iris setosa")
plt.plot(X[:, 0][iris["target"]==1], X[:, 1][iris["target"]==1], "y.", label="Iris versicolor")
plt.plot(X[:, 0][iris["target"]==2], X[:, 1][iris["target"]==2], "r.", label="Iris virginica")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=14)
plt.show()

# %%
X = iris["data"][:, (2,3)] # petal length, petal width 
y = (iris["target"] == 2).astype(np.float64) # Iris virginica

# %%
svm_clf = Pipeline([ ("scalar", StandardScaler()), ("linear_svc", SVC(kernel="linear", C=1)) ])
svm_clf.fit(X,y)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('linear_svc', SVC(C=1, kernel='linear'))])

# %%
svm_clf.predict([[5.5, 1.5]])
# Out:
# array([1.])
